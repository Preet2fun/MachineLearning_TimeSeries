# %%
import pandas as pd
df = pd.read_csv('sample_data.csv')

# %%
pwd
# Out:
# 'C:\\Users\\Dhurvi\\PycharmProjects\\ML\\ML Concepts\\pre-req'

# %%
df.to_csv('sample_data_convert.csv')

# %%
df.to_csv('sample_data_convert.csv', index=False)

# %%
df.shape
# Out:
# (35064, 18)

# %%
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df.tail(10)
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO     O3  \
# 35054  35055  2017      2   28    14    5.0   5.0   4.0   8.0  100.0  117.0
# 35055  35056  2017      2   28    15    6.0  19.0   4.0   8.0  100.0  122.0
# 35056  35057  2017      2   28    16   12.0  18.0   5.0   9.0  200.0  122.0
# 35057  35058  2017      2   28    17   12.0  23.0   6.0  13.0  200.0  120.0
# 35058  35059  2017      2   28    18   13.0  29.0   5.0  22.0  300.0  109.0
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0   95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0   81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0   58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0   35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0   42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 35054  14.6  1013.3 -15.6   0.0    N   3.6  Aotizhongxin
# ...

# %%
df.dtypes
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM2.5      float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# wd          object
# WSPM       float64
# station     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# 5   6  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2
# 6   7  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6
# 7   8  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6
# 8   9  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1
# 9  10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# ...

# %%
df.iloc[1,2]
# Out:
# 3

# %%
df.iloc[0:5,5]
# Out:
# 0    4.0
# 1    8.0
# 2    7.0
# 3    6.0
# 4    3.0
# Name: PM2.5, dtype: float64

# %%
df.iloc[0:5,PM2.5]
# Out:
#   File "<ipython-input-17-c00d416aff6f>", line 1
#     df.iloc[0:5,PM2.5]
#                    ^
# SyntaxError: invalid syntax

# %%
df.loc[0:5,PM2.5]
# Out:
#   File "<ipython-input-18-0685271e5a7b>", line 1
#     df.loc[0:5,PM2.5]
#                   ^
# SyntaxError: invalid syntax

# %%
df.iloc[0:5,'PM2.5']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\dhurvi\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     722             try:
# --> 723                 self._validate_key(k, i)
#     724             except ValueError as err:
#
# c:\users\dhurvi\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1374         else:
# -> 1375             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1376
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
df.loc[0:5,'PM2.5']
# Out:
# 0    4.0
# 1    8.0
# 2    7.0
# 3    6.0
# 4    3.0
# 5    5.0
# Name: PM2.5, dtype: float64

# %%
df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# 5   6  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2
# 6   7  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6
# 7   8  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6
# 8   9  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1
# 9  10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# ...

# %%
df.loc[0:5,'year':'co']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dhurvi\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'co'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-db8a36e4d882> in <module>
# ...

# %%
df.head(5)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df.loc[0:5,['year','PM2.5','CO']]
# Out:
#    year  PM2.5     CO
# 0  2013    4.0  300.0
# 1  2013    8.0  300.0
# 2  2013    7.0  300.0
# 3  2013    6.0  300.0
# 4  2013    3.0  300.0
# 5  2013    5.0  400.0

# %%
df.PM2.5
# Out:
#   File "<ipython-input-25-5f4b8eec0e1b>", line 1
#     df.PM2.5
#           ^
# SyntaxError: invalid syntax

# %%
df.PM10
# Out:
# 0         4.0
# 1         8.0
# 2         7.0
# 3         6.0
# 4         3.0
#          ...
# 35059    29.0
# 35060    37.0
# 35061    37.0
# 35062    44.0
# 35063    31.0
# Name: PM10, Length: 35064, dtype: float64

# %%
df['PM2.5']
# Out:
# 0         4.0
# 1         8.0
# 2         7.0
# 3         6.0
# 4         3.0
#          ...
# 35059    12.0
# 35060    13.0
# 35061    16.0
# 35062    21.0
# 35063    19.0
# Name: PM2.5, Length: 35064, dtype: float64

# %%
df[['PM2.5','PM10']]
# Out:
#        PM2.5  PM10
# 0        4.0   4.0
# 1        8.0   8.0
# 2        7.0   7.0
# 3        6.0   6.0
# 4        3.0   3.0
# ...      ...   ...
# 35059   12.0  29.0
# 35060   13.0  37.0
# 35061   16.0  37.0
# 35062   21.0  44.0
# 35063   19.0  31.0
#
# [35064 rows x 2 columns]

# %%
df[['PM2.5','PM10']] == '8.0'
# Out:
#        PM2.5   PM10
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 35059  False  False
# 35060  False  False
# 35061  False  False
# 35062  False  False
# 35063  False  False
#
# [35064 rows x 2 columns]

# %%
df[['PM2.5','PM10']] == 8.0
# Out:
#        PM2.5   PM10
# 0      False  False
# 1       True   True
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 35059  False  False
# 35060  False  False
# 35061  False  False
# 35062  False  False
# 35063  False  False
#
# [35064 rows x 2 columns]

# %%
df[df.PM10 == 8.0]
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO     O3  \
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0   77.0
# 9         10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0   59.0
# 295      296  2013      3   13     7    3.0   8.0  21.0  40.0  600.0   69.0
# 565      566  2013      3   24    13    3.0   8.0  12.0  12.0    NaN   76.0
# 566      567  2013      3   24    14    4.0   8.0  10.0  12.0    NaN   78.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...    ...
# 34788  34789  2017      2   17    12    8.0   8.0   2.0  10.0  200.0   78.0
# 34789  34790  2017      2   17    13    8.0   8.0   4.0   9.0  200.0   81.0
# 34971  34972  2017      2   25     3    7.0   8.0   5.0  46.0  400.0   49.0
# 35051  35052  2017      2   28    11    7.0   8.0   4.0  12.0  200.0  107.0
# 35053  35054  2017      2   28    13    6.0   8.0   3.0   9.0  100.0  115.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
df1 = df

# %%
df1
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
df1.PM10 = 100

# %%
df1
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   100   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   100   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   100   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   100  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   100  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0   100   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0   100   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0   100  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0   100  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0   100  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   100   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   100   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   100   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   100  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   100  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0   100   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0   100   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0   100  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0   100  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0   100  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
df.describe(include = 'object')
# Out:
#            wd       station
# count   34983         35064
# unique     16             1
# top        NE  Aotizhongxin
# freq     5140         35064

# %%
df.describe(include = 'all')
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
df.describe(include='all')
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
df['PM2.5'].describe()
# Out:
# count    34139.000000
# mean        82.773611
# std         82.135694
# min          3.000000
# 25%         22.000000
# 50%         58.000000
# 75%        114.000000
# max        898.000000
# Name: PM2.5, dtype: float64

# %%
df.mean()
# Out:
# No       17532.500000
# year      2014.662560
# month        6.522930
# day         15.729637
# hour        11.500000
# PM2.5       82.773611
# PM10       110.060391
# SO2         17.375901
# NO2         59.305833
# CO        1262.945145
# O3          56.353358
# TEMP        13.584607
# PRES      1011.846920
# DEWP         3.123062
# RAIN         0.067421
# WSPM         1.708496
# dtype: float64

# %%
df.PM10.unique()
# Out:
# array([  4. ,   8. ,   7. ,   6. ,   3. ,   5. ,   9. ,  15. ,  19. ,
#         23. ,  20. ,  14. ,  17. ,  18. ,  24. ,  13. ,  11. ,  10. ,
#         29. ,  30. ,  33. ,  35. ,  40. ,  46. ,  58. ,  79. ,  86. ,
#         96. , 103. , 113. , 120. , 130. , 132. , 129. , 136. , 135. ,
#        142. , 116. , 110. , 119. , 122. , 117. , 108. , 134. , 106. ,
#        114. , 100. ,  82. ,  71. , 175. , 181. , 105. ,  94. ,  83. ,
#         80. ,  62. ,  34. ,  32. ,  36. ,  28. ,  12. ,  44. ,  63. ,
#         84. ,  85. ,  91. , 127. , 151. , 153. , 145. , 146. , 147. ,
#        159. , 177. , 184. , 193. , 182. , 171. , 186. , 218. , 248. ,
#        255. , 244. , 252. , 253. , 269. , 315. , 300. , 265. , 229. ,
#        203. , 194. , 196. , 205. , 198. , 212. , 219. , 233. , 277. ,
#        285. , 276. , 291. , 338. , 396. , 380. , 335. , 360. , 319. ,
#        297. , 294. , 293. , 304. , 337. , 366. , 374. , 344. , 282. ,
# ...

# %%
df.station.unique()
# Out:
# array(['Aotizhongxin'], dtype=object)

# %%
df.PM10.value_counts()
#df.station.value_counts()
# Out:
# 6.0      345
# 18.0     322
# 22.0     313
# 14.0     299
# 23.0     296
#         ...
# 64.7       1
# 466.0      1
# 675.0      1
# 112.2      1
# 484.0      1
# Name: PM10, Length: 633, dtype: int64

# %%
df.sort_values(by = 'CO', ascending = False ).head(10)
# Out:
#           No  year  month  day  hour  PM2.5   PM10  SO2   NO2     CO     O3  \
# 30558  30559  2016      8   25     6    3.0    6.0  2.0  10.0  100.0  102.0
# 12531  12532  2014      8    5     3   11.0   11.0  2.0  35.0  100.0    9.0
# 21263  21264  2015      8    3    23   11.0   19.0  2.0  40.0  100.0   58.0
# 21264  21265  2015      8    4     0    9.0   16.0  2.0  35.0  100.0   62.0
# 21265  21266  2015      8    4     1    7.0   13.0  2.0  46.0  100.0   50.0
# 21266  21267  2015      8    4     2    8.0   19.0  3.0  45.0  100.0   47.0
# 21267  21268  2015      8    4     3    8.0   35.0  3.0  65.0  100.0   24.0
# 19299  19300  2015      5   14     3   11.0   53.0  2.0  13.0  100.0   96.0
# 29080  29081  2016      6   24    16   10.0   36.0  2.0  11.0  100.0   97.0
# 19298  19299  2015      5   14     2   33.0  180.0  3.0  16.0  100.0   85.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 30558  28.4  1003.0  13.9   0.0  NNW   3.5  Aotizhongxin
# ...

# %%
pd.__version__
# Out:
# '1.2.2'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=35064, step=1)

# %%
data = pd.Series(['manu','RM','Barca'], index=[1,3,5])

# %%
data
# Out:
# 1     manu
# 3       RM
# 5    Barca
# dtype: object

# %%
data.loc[1]
# Out:
# 'manu'

# %%
data.iloc[1]
# Out:
# 'RM'

# %%
import numpy as np

# %%
data1 = pd.DataFrame[[10,'pratik',np.nan],['delta',-1,10.5],[None,2,8.0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6b019c181988> in <module>
# ----> 1 data1 = pd.DataFrame[[10,'pratik',np.nan],['delta',-1,10.5],[None,2,8.0]]
#
# TypeError: 'type' object is not subscriptable

# %%
df = [[1,2.2,-1,'data1'],['pratik',np.nan,0.06],[-5,3443.3,'data2']]

# %%
data1 = pd.DataFrame(df,columns=['a','b','c','d'],index=[1,2,3])

# %%
data1
# Out:
#         a       b      c      d
# 1       1     2.2     -1  data1
# 2  pratik     NaN   0.06   None
# 3      -5  3443.3  data2   None

# %%
data1.isnull()
# Out:
#        a      b      c      d
# 1  False  False  False  False
# 2  False   True  False   True
# 3  False  False  False   True

# %%
data1.isnull().sum()
# Out:
# a    0
# b    1
# c    0
# d    2
# dtype: int64

# %%
data1.fillna('unknown')
# Out:
#         a        b      c        d
# 1       1      2.2     -1    data1
# 2  pratik  unknown   0.06  unknown
# 3      -5   3443.3  data2  unknown

# %%
data1['b'].fillna(data1['b'].mean(), inplace= True)

# %%
data1.b
# Out:
# 1       2.20
# 2    1722.75
# 3    3443.30
# Name: b, dtype: float64

# %%
data1.fillna(method='ffill', axis=1)
# Out:
#         a        b      c      d
# 1       1      2.2     -1  data1
# 2  pratik  1722.75   0.06   0.06
# 3      -5   3443.3  data2  data2
